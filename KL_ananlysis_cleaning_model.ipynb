# %%
#importing data management, data visualisation libraries.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data= pd.read_csv('KL_no_null_data.csv')
data.drop(columns="Unnamed: 0", inplace= True)
data
# Out:
#                                 Location         Price Rooms  Bathrooms  \
# 0                     KLCC, Kuala Lumpur  RM 1,250,000   2+1        3.0
# 1                  Dutamas, Kuala Lumpur  RM 1,030,000     3        4.0
# 2              Bukit Jalil, Kuala Lumpur    RM 900,000   4+1        3.0
# 3      Taman Tun Dr Ismail, Kuala Lumpur  RM 5,350,000   4+2        5.0
# 4      Taman Tun Dr Ismail, Kuala Lumpur  RM 2,600,000     5        4.0
# ...                                  ...           ...   ...        ...
# 31894              Seputeh, Kuala Lumpur    RM 750,000     3        2.0
# 31895           KL Sentral, Kuala Lumpur  RM 1,400,000   3+1        3.0
# 31896          KL Eco City, Kuala Lumpur    RM 880,000     1        1.0
# 31897         Sri Hartamas, Kuala Lumpur  RM 2,700,000   4+2        6.0
# 31898              Setapak, Kuala Lumpur    RM 540,000     4        2.0
#
#        Car Parks               Property Type                      Size  \
# 0            2.0          Serviced Residence  Built-up : 1,335 sq. ft.
# 1            2.0        Condominium (Corner)  Built-up : 1,875 sq. ft.
# 2            2.0        Condominium (Corner)  Built-up : 1,513 sq. ft.
# 3            4.0                    Bungalow  Land area : 7200 sq. ft.
# 4            4.0         Semi-detached House  Land area : 3600 sq. ft.
# ...          ...                         ...                       ...
# 31894        1.0                 Condominium    Built-up : 915 sq. ft.
# 31895        2.0        Condominium (Corner)  Land area : 1544 sq. ft.
# 31896        1.0        Condominium (Corner)    Built-up : 650 sq. ft.
# 31897        3.0        Condominium (Corner)  Built-up : 3,973 sq. ft.
# 31898        3.0  Condominium (Intermediate)  Built-up : 1,313 sq. ft.
#
#              Furnishing
# 0       Fully Furnished
# 1      Partly Furnished
# 2      Partly Furnished
# 3      Partly Furnished
# 4      Partly Furnished
# ...                 ...
# 31894  Partly Furnished
# 31895   Fully Furnished
# 31896  Partly Furnished
# 31897  Partly Furnished
# 31898  Partly Furnished
#
# [31899 rows x 8 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31899 entries, 0 to 31898
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Location       31899 non-null  object
#  1   Price          31899 non-null  object
#  2   Rooms          31899 non-null  object
#  3   Bathrooms      31899 non-null  float64
#  4   Car Parks      31899 non-null  float64
#  5   Property Type  31899 non-null  object
#  6   Size           31899 non-null  object
#  7   Furnishing     31899 non-null  object
# dtypes: float64(2), object(6)
# memory usage: 1.9+ MB

# %%
data.dtypes
# Out:
# Location          object
# Price             object
# Rooms             object
# Bathrooms        float64
# Car Parks        float64
# Property Type     object
# Size              object
# Furnishing        object
# dtype: object

# %%
data.describe().T
# Out:
#              count      mean       std  min  25%  50%  75%   max
# Bathrooms  31899.0  2.936236  1.532726  1.0  2.0  2.0  4.0  20.0
# Car Parks  31899.0  2.013449  1.308361  1.0  1.0  2.0  2.0  30.0

# %%
data.duplicated().sum()
# Out:
# 2867

# %%
data.drop_duplicates(inplace=True)

# %%
data.reset_index(drop=True, inplace=True)

# %%
data.to_csv("KL_no_null_no_duplicates.csv")

# %%
data
# Out:
#                                 Location         Price Rooms  Bathrooms  \
# 0                     KLCC, Kuala Lumpur  RM 1,250,000   2+1        3.0
# 1                  Dutamas, Kuala Lumpur  RM 1,030,000     3        4.0
# 2              Bukit Jalil, Kuala Lumpur    RM 900,000   4+1        3.0
# 3      Taman Tun Dr Ismail, Kuala Lumpur  RM 5,350,000   4+2        5.0
# 4      Taman Tun Dr Ismail, Kuala Lumpur  RM 2,600,000     5        4.0
# ...                                  ...           ...   ...        ...
# 29027              Seputeh, Kuala Lumpur    RM 750,000     3        2.0
# 29028           KL Sentral, Kuala Lumpur  RM 1,400,000   3+1        3.0
# 29029          KL Eco City, Kuala Lumpur    RM 880,000     1        1.0
# 29030         Sri Hartamas, Kuala Lumpur  RM 2,700,000   4+2        6.0
# 29031              Setapak, Kuala Lumpur    RM 540,000     4        2.0
#
#        Car Parks               Property Type                      Size  \
# 0            2.0          Serviced Residence  Built-up : 1,335 sq. ft.
# 1            2.0        Condominium (Corner)  Built-up : 1,875 sq. ft.
# 2            2.0        Condominium (Corner)  Built-up : 1,513 sq. ft.
# 3            4.0                    Bungalow  Land area : 7200 sq. ft.
# 4            4.0         Semi-detached House  Land area : 3600 sq. ft.
# ...          ...                         ...                       ...
# 29027        1.0                 Condominium    Built-up : 915 sq. ft.
# 29028        2.0        Condominium (Corner)  Land area : 1544 sq. ft.
# 29029        1.0        Condominium (Corner)    Built-up : 650 sq. ft.
# 29030        3.0        Condominium (Corner)  Built-up : 3,973 sq. ft.
# 29031        3.0  Condominium (Intermediate)  Built-up : 1,313 sq. ft.
#
#              Furnishing
# 0       Fully Furnished
# 1      Partly Furnished
# 2      Partly Furnished
# 3      Partly Furnished
# 4      Partly Furnished
# ...                 ...
# 29027  Partly Furnished
# 29028   Fully Furnished
# 29029  Partly Furnished
# 29030  Partly Furnished
# 29031  Partly Furnished
#
# [29032 rows x 8 columns]

# %%
#Cleaning Location column
# Split the column with commas into two separate columns
data[['area', 'L2', 'L3']] = data['Location'].str.split(',' ,expand=True)
data.drop(columns=["Location","L2","L3"], inplace=True)
data
# Out:
#               Price Rooms  Bathrooms  Car Parks               Property Type  \
# 0      RM 1,250,000   2+1        3.0        2.0          Serviced Residence
# 1      RM 1,030,000     3        4.0        2.0        Condominium (Corner)
# 2        RM 900,000   4+1        3.0        2.0        Condominium (Corner)
# 3      RM 5,350,000   4+2        5.0        4.0                    Bungalow
# 4      RM 2,600,000     5        4.0        4.0         Semi-detached House
# ...             ...   ...        ...        ...                         ...
# 29027    RM 750,000     3        2.0        1.0                 Condominium
# 29028  RM 1,400,000   3+1        3.0        2.0        Condominium (Corner)
# 29029    RM 880,000     1        1.0        1.0        Condominium (Corner)
# 29030  RM 2,700,000   4+2        6.0        3.0        Condominium (Corner)
# 29031    RM 540,000     4        2.0        3.0  Condominium (Intermediate)
#
#                            Size        Furnishing                 area
# 0      Built-up : 1,335 sq. ft.   Fully Furnished                 KLCC
# 1      Built-up : 1,875 sq. ft.  Partly Furnished              Dutamas
# 2      Built-up : 1,513 sq. ft.  Partly Furnished          Bukit Jalil
# 3      Land area : 7200 sq. ft.  Partly Furnished  Taman Tun Dr Ismail
# 4      Land area : 3600 sq. ft.  Partly Furnished  Taman Tun Dr Ismail
# ...                         ...               ...                  ...
# 29027    Built-up : 915 sq. ft.  Partly Furnished              Seputeh
# 29028  Land area : 1544 sq. ft.   Fully Furnished           KL Sentral
# 29029    Built-up : 650 sq. ft.  Partly Furnished          KL Eco City
# 29030  Built-up : 3,973 sq. ft.  Partly Furnished         Sri Hartamas
# 29031  Built-up : 1,313 sq. ft.  Partly Furnished              Setapak
#
# [29032 rows x 8 columns]

# %%
#Cleaning Price column
data['Price'] = data['Price'].str.replace(r'\D+', '', regex=True).astype(int)

data
# Out:
#          Price Rooms  Bathrooms  Car Parks               Property Type  \
# 0      1250000   2+1        3.0        2.0          Serviced Residence
# 1      1030000     3        4.0        2.0        Condominium (Corner)
# 2       900000   4+1        3.0        2.0        Condominium (Corner)
# 3      5350000   4+2        5.0        4.0                    Bungalow
# 4      2600000     5        4.0        4.0         Semi-detached House
# ...        ...   ...        ...        ...                         ...
# 29027   750000     3        2.0        1.0                 Condominium
# 29028  1400000   3+1        3.0        2.0        Condominium (Corner)
# 29029   880000     1        1.0        1.0        Condominium (Corner)
# 29030  2700000   4+2        6.0        3.0        Condominium (Corner)
# 29031   540000     4        2.0        3.0  Condominium (Intermediate)
#
#                            Size        Furnishing                 area
# 0      Built-up : 1,335 sq. ft.   Fully Furnished                 KLCC
# 1      Built-up : 1,875 sq. ft.  Partly Furnished              Dutamas
# 2      Built-up : 1,513 sq. ft.  Partly Furnished          Bukit Jalil
# 3      Land area : 7200 sq. ft.  Partly Furnished  Taman Tun Dr Ismail
# 4      Land area : 3600 sq. ft.  Partly Furnished  Taman Tun Dr Ismail
# ...                         ...               ...                  ...
# 29027    Built-up : 915 sq. ft.  Partly Furnished              Seputeh
# 29028  Land area : 1544 sq. ft.   Fully Furnished           KL Sentral
# 29029    Built-up : 650 sq. ft.  Partly Furnished          KL Eco City
# 29030  Built-up : 3,973 sq. ft.  Partly Furnished         Sri Hartamas
# 29031  Built-up : 1,313 sq. ft.  Partly Furnished              Setapak
#
# [29032 rows x 8 columns]

# %%
# Splitting the Rooms column and creating two new columns, no of bed room, servant rooms
data[['No_of_Bedrooms', 'No_of_servant_rooms']] = data['Rooms'].str.split('+', expand=True)
data.drop(columns="Rooms", inplace=True)

# %%
data['No_of_servant_rooms'].isna().sum()
# Out:
# 17243

# %%
data['No_of_servant_rooms'].fillna(value=0, inplace=True)

# %%
data
# Out:
#          Price  Bathrooms  Car Parks               Property Type  \
# 0      1250000        3.0        2.0          Serviced Residence
# 1      1030000        4.0        2.0        Condominium (Corner)
# 2       900000        3.0        2.0        Condominium (Corner)
# 3      5350000        5.0        4.0                    Bungalow
# 4      2600000        4.0        4.0         Semi-detached House
# ...        ...        ...        ...                         ...
# 29027   750000        2.0        1.0                 Condominium
# 29028  1400000        3.0        2.0        Condominium (Corner)
# 29029   880000        1.0        1.0        Condominium (Corner)
# 29030  2700000        6.0        3.0        Condominium (Corner)
# 29031   540000        2.0        3.0  Condominium (Intermediate)
#
#                            Size        Furnishing                 area  \
# 0      Built-up : 1,335 sq. ft.   Fully Furnished                 KLCC
# 1      Built-up : 1,875 sq. ft.  Partly Furnished              Dutamas
# 2      Built-up : 1,513 sq. ft.  Partly Furnished          Bukit Jalil
# 3      Land area : 7200 sq. ft.  Partly Furnished  Taman Tun Dr Ismail
# 4      Land area : 3600 sq. ft.  Partly Furnished  Taman Tun Dr Ismail
# ...                         ...               ...                  ...
# 29027    Built-up : 915 sq. ft.  Partly Furnished              Seputeh
# 29028  Land area : 1544 sq. ft.   Fully Furnished           KL Sentral
# 29029    Built-up : 650 sq. ft.  Partly Furnished          KL Eco City
# 29030  Built-up : 3,973 sq. ft.  Partly Furnished         Sri Hartamas
# 29031  Built-up : 1,313 sq. ft.  Partly Furnished              Setapak
#
#       No_of_Bedrooms No_of_servant_rooms
# 0                  2                   1
# 1                  3                   0
# 2                  4                   1
# 3                  4                   2
# 4                  5                   0
# ...              ...                 ...
# 29027              3                   0
# 29028              3                   1
# 29029              1                   0
# 29030              4                   2
# 29031              4                   0
#
# [29032 rows x 9 columns]

# %%
#cleaing Size column:

# Extract type and number using regular expressions
data[['type', 'size']] = data['Size'].str.extract(r'([^:]+)\s*:\s*([\d,]+)\s*sq\. ft')
data
# Out:
#          Price  Bathrooms  Car Parks               Property Type  \
# 0      1250000        3.0        2.0          Serviced Residence
# 1      1030000        4.0        2.0        Condominium (Corner)
# 2       900000        3.0        2.0        Condominium (Corner)
# 3      5350000        5.0        4.0                    Bungalow
# 4      2600000        4.0        4.0         Semi-detached House
# ...        ...        ...        ...                         ...
# 29027   750000        2.0        1.0                 Condominium
# 29028  1400000        3.0        2.0        Condominium (Corner)
# 29029   880000        1.0        1.0        Condominium (Corner)
# 29030  2700000        6.0        3.0        Condominium (Corner)
# 29031   540000        2.0        3.0  Condominium (Intermediate)
#
#                            Size        Furnishing                 area  \
# 0      Built-up : 1,335 sq. ft.   Fully Furnished                 KLCC
# 1      Built-up : 1,875 sq. ft.  Partly Furnished              Dutamas
# 2      Built-up : 1,513 sq. ft.  Partly Furnished          Bukit Jalil
# 3      Land area : 7200 sq. ft.  Partly Furnished  Taman Tun Dr Ismail
# 4      Land area : 3600 sq. ft.  Partly Furnished  Taman Tun Dr Ismail
# ...                         ...               ...                  ...
# 29027    Built-up : 915 sq. ft.  Partly Furnished              Seputeh
# 29028  Land area : 1544 sq. ft.   Fully Furnished           KL Sentral
# 29029    Built-up : 650 sq. ft.  Partly Furnished          KL Eco City
# 29030  Built-up : 3,973 sq. ft.  Partly Furnished         Sri Hartamas
# 29031  Built-up : 1,313 sq. ft.  Partly Furnished              Setapak
#
#       No_of_Bedrooms No_of_servant_rooms        type   size
# 0                  2                   1   Built-up   1,335
# 1                  3                   0   Built-up   1,875
# 2                  4                   1   Built-up   1,513
# 3                  4                   2  Land area    7200
# 4                  5                   0  Land area    3600
# ...              ...                 ...         ...    ...
# 29027              3                   0   Built-up     915
# 29028              3                   1  Land area    1544
# 29029              1                   0   Built-up     650
# 29030              4                   2   Built-up   3,973
# 29031              4                   0   Built-up   1,313
#
# [29032 rows x 11 columns]

# %%
data['size'] = data['size'].str.replace(',', '')
data
# Out:
#          Price  Bathrooms  Car Parks               Property Type  \
# 0      1250000        3.0        2.0          Serviced Residence
# 1      1030000        4.0        2.0        Condominium (Corner)
# 2       900000        3.0        2.0        Condominium (Corner)
# 3      5350000        5.0        4.0                    Bungalow
# 4      2600000        4.0        4.0         Semi-detached House
# ...        ...        ...        ...                         ...
# 29027   750000        2.0        1.0                 Condominium
# 29028  1400000        3.0        2.0        Condominium (Corner)
# 29029   880000        1.0        1.0        Condominium (Corner)
# 29030  2700000        6.0        3.0        Condominium (Corner)
# 29031   540000        2.0        3.0  Condominium (Intermediate)
#
#                            Size        Furnishing                 area  \
# 0      Built-up : 1,335 sq. ft.   Fully Furnished                 KLCC
# 1      Built-up : 1,875 sq. ft.  Partly Furnished              Dutamas
# 2      Built-up : 1,513 sq. ft.  Partly Furnished          Bukit Jalil
# 3      Land area : 7200 sq. ft.  Partly Furnished  Taman Tun Dr Ismail
# 4      Land area : 3600 sq. ft.  Partly Furnished  Taman Tun Dr Ismail
# ...                         ...               ...                  ...
# 29027    Built-up : 915 sq. ft.  Partly Furnished              Seputeh
# 29028  Land area : 1544 sq. ft.   Fully Furnished           KL Sentral
# 29029    Built-up : 650 sq. ft.  Partly Furnished          KL Eco City
# 29030  Built-up : 3,973 sq. ft.  Partly Furnished         Sri Hartamas
# 29031  Built-up : 1,313 sq. ft.  Partly Furnished              Setapak
#
#       No_of_Bedrooms No_of_servant_rooms        type  size
# 0                  2                   1   Built-up   1335
# 1                  3                   0   Built-up   1875
# 2                  4                   1   Built-up   1513
# 3                  4                   2  Land area   7200
# 4                  5                   0  Land area   3600
# ...              ...                 ...         ...   ...
# 29027              3                   0   Built-up    915
# 29028              3                   1  Land area   1544
# 29029              1                   0   Built-up    650
# 29030              4                   2   Built-up   3973
# 29031              4                   0   Built-up   1313
#
# [29032 rows x 11 columns]

# %%
data['size'].isna().sum()
# Out:
# 2541

# %%
# Convert 'Bathrooms' column to integer
data['Bathrooms'] = data['Bathrooms'].astype(int)
data
# Out:
#          Price  Bathrooms  Car Parks               Property Type  \
# 0      1250000          3        2.0          Serviced Residence
# 1      1030000          4        2.0        Condominium (Corner)
# 2       900000          3        2.0        Condominium (Corner)
# 3      5350000          5        4.0                    Bungalow
# 4      2600000          4        4.0         Semi-detached House
# ...        ...        ...        ...                         ...
# 29027   750000          2        1.0                 Condominium
# 29028  1400000          3        2.0        Condominium (Corner)
# 29029   880000          1        1.0        Condominium (Corner)
# 29030  2700000          6        3.0        Condominium (Corner)
# 29031   540000          2        3.0  Condominium (Intermediate)
#
#                            Size        Furnishing                 area  \
# 0      Built-up : 1,335 sq. ft.   Fully Furnished                 KLCC
# 1      Built-up : 1,875 sq. ft.  Partly Furnished              Dutamas
# 2      Built-up : 1,513 sq. ft.  Partly Furnished          Bukit Jalil
# 3      Land area : 7200 sq. ft.  Partly Furnished  Taman Tun Dr Ismail
# 4      Land area : 3600 sq. ft.  Partly Furnished  Taman Tun Dr Ismail
# ...                         ...               ...                  ...
# 29027    Built-up : 915 sq. ft.  Partly Furnished              Seputeh
# 29028  Land area : 1544 sq. ft.   Fully Furnished           KL Sentral
# 29029    Built-up : 650 sq. ft.  Partly Furnished          KL Eco City
# 29030  Built-up : 3,973 sq. ft.  Partly Furnished         Sri Hartamas
# 29031  Built-up : 1,313 sq. ft.  Partly Furnished              Setapak
#
#       No_of_Bedrooms No_of_servant_rooms        type  size
# 0                  2                   1   Built-up   1335
# 1                  3                   0   Built-up   1875
# 2                  4                   1   Built-up   1513
# 3                  4                   2  Land area   7200
# 4                  5                   0  Land area   3600
# ...              ...                 ...         ...   ...
# 29027              3                   0   Built-up    915
# 29028              3                   1  Land area   1544
# 29029              1                   0   Built-up    650
# 29030              4                   2   Built-up   3973
# 29031              4                   0   Built-up   1313
#
# [29032 rows x 11 columns]

# %%
# Convert 'Car Parks' column to integer
data['Car Parks'] = data['Car Parks'].astype(int)
data
# Out:
#          Price  Bathrooms  Car Parks               Property Type  \
# 0      1250000          3          2          Serviced Residence
# 1      1030000          4          2        Condominium (Corner)
# 2       900000          3          2        Condominium (Corner)
# 3      5350000          5          4                    Bungalow
# 4      2600000          4          4         Semi-detached House
# ...        ...        ...        ...                         ...
# 29027   750000          2          1                 Condominium
# 29028  1400000          3          2        Condominium (Corner)
# 29029   880000          1          1        Condominium (Corner)
# 29030  2700000          6          3        Condominium (Corner)
# 29031   540000          2          3  Condominium (Intermediate)
#
#                            Size        Furnishing                 area  \
# 0      Built-up : 1,335 sq. ft.   Fully Furnished                 KLCC
# 1      Built-up : 1,875 sq. ft.  Partly Furnished              Dutamas
# 2      Built-up : 1,513 sq. ft.  Partly Furnished          Bukit Jalil
# 3      Land area : 7200 sq. ft.  Partly Furnished  Taman Tun Dr Ismail
# 4      Land area : 3600 sq. ft.  Partly Furnished  Taman Tun Dr Ismail
# ...                         ...               ...                  ...
# 29027    Built-up : 915 sq. ft.  Partly Furnished              Seputeh
# 29028  Land area : 1544 sq. ft.   Fully Furnished           KL Sentral
# 29029    Built-up : 650 sq. ft.  Partly Furnished          KL Eco City
# 29030  Built-up : 3,973 sq. ft.  Partly Furnished         Sri Hartamas
# 29031  Built-up : 1,313 sq. ft.  Partly Furnished              Setapak
#
#       No_of_Bedrooms No_of_servant_rooms        type  size
# 0                  2                   1   Built-up   1335
# 1                  3                   0   Built-up   1875
# 2                  4                   1   Built-up   1513
# 3                  4                   2  Land area   7200
# 4                  5                   0  Land area   3600
# ...              ...                 ...         ...   ...
# 29027              3                   0   Built-up    915
# 29028              3                   1  Land area   1544
# 29029              1                   0   Built-up    650
# 29030              4                   2   Built-up   3973
# 29031              4                   0   Built-up   1313
#
# [29032 rows x 11 columns]

# %%
data
# Out:
#          Price  Bathrooms  Car Parks               Property Type  \
# 0      1250000          3          2          Serviced Residence
# 1      1030000          4          2        Condominium (Corner)
# 2       900000          3          2        Condominium (Corner)
# 3      5350000          5          4                    Bungalow
# 4      2600000          4          4         Semi-detached House
# ...        ...        ...        ...                         ...
# 29027   750000          2          1                 Condominium
# 29028  1400000          3          2        Condominium (Corner)
# 29029   880000          1          1        Condominium (Corner)
# 29030  2700000          6          3        Condominium (Corner)
# 29031   540000          2          3  Condominium (Intermediate)
#
#                            Size        Furnishing                 area  \
# 0      Built-up : 1,335 sq. ft.   Fully Furnished                 KLCC
# 1      Built-up : 1,875 sq. ft.  Partly Furnished              Dutamas
# 2      Built-up : 1,513 sq. ft.  Partly Furnished          Bukit Jalil
# 3      Land area : 7200 sq. ft.  Partly Furnished  Taman Tun Dr Ismail
# 4      Land area : 3600 sq. ft.  Partly Furnished  Taman Tun Dr Ismail
# ...                         ...               ...                  ...
# 29027    Built-up : 915 sq. ft.  Partly Furnished              Seputeh
# 29028  Land area : 1544 sq. ft.   Fully Furnished           KL Sentral
# 29029    Built-up : 650 sq. ft.  Partly Furnished          KL Eco City
# 29030  Built-up : 3,973 sq. ft.  Partly Furnished         Sri Hartamas
# 29031  Built-up : 1,313 sq. ft.  Partly Furnished              Setapak
#
#       No_of_Bedrooms No_of_servant_rooms        type  size
# 0                  2                   1   Built-up   1335
# 1                  3                   0   Built-up   1875
# 2                  4                   1   Built-up   1513
# 3                  4                   2  Land area   7200
# 4                  5                   0  Land area   3600
# ...              ...                 ...         ...   ...
# 29027              3                   0   Built-up    915
# 29028              3                   1  Land area   1544
# 29029              1                   0   Built-up    650
# 29030              4                   2   Built-up   3973
# 29031              4                   0   Built-up   1313
#
# [29032 rows x 11 columns]

# %%
data.isna().sum()
# Out:
# Price                     0
# Bathrooms                 0
# Car Parks                 0
# Property Type             0
# Size                      0
# Furnishing                0
# area                      0
# No_of_Bedrooms            0
# No_of_servant_rooms       0
# type                   2541
# size                   2541
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29032 entries, 0 to 29031
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Price                29032 non-null  int32
#  1   Bathrooms            29032 non-null  int32
#  2   Car Parks            29032 non-null  int32
#  3   Property Type        29032 non-null  object
#  4   Size                 29032 non-null  object
#  5   Furnishing           29032 non-null  object
#  6   area                 29032 non-null  object
#  7   No_of_Bedrooms       29032 non-null  object
#  8   No_of_servant_rooms  29032 non-null  object
#  9   type                 26491 non-null  object
#  10  size                 26491 non-null  object
# dtypes: int32(3), object(8)
# memory usage: 2.1+ MB

# %%
data= data.dropna()
data.reset_index(drop=True, inplace=True) 
data
# Out:
#          Price  Bathrooms  Car Parks               Property Type  \
# 0      1250000          3          2          Serviced Residence
# 1      1030000          4          2        Condominium (Corner)
# 2       900000          3          2        Condominium (Corner)
# 3      5350000          5          4                    Bungalow
# 4      2600000          4          4         Semi-detached House
# ...        ...        ...        ...                         ...
# 26486   750000          2          1                 Condominium
# 26487  1400000          3          2        Condominium (Corner)
# 26488   880000          1          1        Condominium (Corner)
# 26489  2700000          6          3        Condominium (Corner)
# 26490   540000          2          3  Condominium (Intermediate)
#
#                            Size        Furnishing                 area  \
# 0      Built-up : 1,335 sq. ft.   Fully Furnished                 KLCC
# 1      Built-up : 1,875 sq. ft.  Partly Furnished              Dutamas
# 2      Built-up : 1,513 sq. ft.  Partly Furnished          Bukit Jalil
# 3      Land area : 7200 sq. ft.  Partly Furnished  Taman Tun Dr Ismail
# 4      Land area : 3600 sq. ft.  Partly Furnished  Taman Tun Dr Ismail
# ...                         ...               ...                  ...
# 26486    Built-up : 915 sq. ft.  Partly Furnished              Seputeh
# 26487  Land area : 1544 sq. ft.   Fully Furnished           KL Sentral
# 26488    Built-up : 650 sq. ft.  Partly Furnished          KL Eco City
# 26489  Built-up : 3,973 sq. ft.  Partly Furnished         Sri Hartamas
# 26490  Built-up : 1,313 sq. ft.  Partly Furnished              Setapak
#
#       No_of_Bedrooms No_of_servant_rooms        type  size
# 0                  2                   1   Built-up   1335
# 1                  3                   0   Built-up   1875
# 2                  4                   1   Built-up   1513
# 3                  4                   2  Land area   7200
# 4                  5                   0  Land area   3600
# ...              ...                 ...         ...   ...
# 26486              3                   0   Built-up    915
# 26487              3                   1  Land area   1544
# 26488              1                   0   Built-up    650
# 26489              4                   2   Built-up   3973
# 26490              4                   0   Built-up   1313
#
# [26491 rows x 11 columns]

# %%
data['size'] = data['size'].astype(int)
# Out:
# C:\Users\ptejas\AppData\Local\Temp\ipykernel_13904\2008391559.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['size'] = data['size'].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26491 entries, 0 to 26490
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Price                26491 non-null  int32
#  1   Bathrooms            26491 non-null  int32
#  2   Car Parks            26491 non-null  int32
#  3   Property Type        26491 non-null  object
#  4   Size                 26491 non-null  object
#  5   Furnishing           26491 non-null  object
#  6   area                 26491 non-null  object
#  7   No_of_Bedrooms       26491 non-null  object
#  8   No_of_servant_rooms  26491 non-null  object
#  9   type                 26491 non-null  object
#  10  size                 26491 non-null  int32
# dtypes: int32(4), object(7)
# memory usage: 1.8+ MB

# %%
# Use regex to remove non-digit characters and keep only numbers
data['No_of_servant_rooms'] = data['No_of_servant_rooms'].str.replace(r'\D+', '', regex=True)

# Replace empty strings or NaN values with a placeholder value (e.g., '0')
data['No_of_servant_rooms'].replace('', '0', inplace=True)
data['No_of_servant_rooms'].fillna('0', inplace=True)

# Convert the column to integer type
data['No_of_servant_rooms'] = data['No_of_servant_rooms'].astype(int)
# Out:
# C:\Users\ptejas\AppData\Local\Temp\ipykernel_13904\4288363492.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['No_of_servant_rooms'] = data['No_of_servant_rooms'].str.replace(r'\D+', '', regex=True)
# C:\Users\ptejas\AppData\Local\Temp\ipykernel_13904\4288363492.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['No_of_servant_rooms'].replace('', '0', inplace=True)
# C:\Users\ptejas\AppData\Local\Temp\ipykernel_13904\4288363492.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['No_of_servant_rooms'].fillna('0', inplace=True)
# C:\Users\ptejas\AppData\Local\Temp\ipykernel_13904\4288363492.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['No_of_servant_rooms'] = data['No_of_servant_rooms'].astype(int)

# %%
data
# Out:
#          Price  Bathrooms  Car Parks               Property Type  \
# 0      1250000          3          2          Serviced Residence
# 1      1030000          4          2        Condominium (Corner)
# 2       900000          3          2        Condominium (Corner)
# 3      5350000          5          4                    Bungalow
# 4      2600000          4          4         Semi-detached House
# ...        ...        ...        ...                         ...
# 26486   750000          2          1                 Condominium
# 26487  1400000          3          2        Condominium (Corner)
# 26488   880000          1          1        Condominium (Corner)
# 26489  2700000          6          3        Condominium (Corner)
# 26490   540000          2          3  Condominium (Intermediate)
#
#                            Size        Furnishing                 area  \
# 0      Built-up : 1,335 sq. ft.   Fully Furnished                 KLCC
# 1      Built-up : 1,875 sq. ft.  Partly Furnished              Dutamas
# 2      Built-up : 1,513 sq. ft.  Partly Furnished          Bukit Jalil
# 3      Land area : 7200 sq. ft.  Partly Furnished  Taman Tun Dr Ismail
# 4      Land area : 3600 sq. ft.  Partly Furnished  Taman Tun Dr Ismail
# ...                         ...               ...                  ...
# 26486    Built-up : 915 sq. ft.  Partly Furnished              Seputeh
# 26487  Land area : 1544 sq. ft.   Fully Furnished           KL Sentral
# 26488    Built-up : 650 sq. ft.  Partly Furnished          KL Eco City
# 26489  Built-up : 3,973 sq. ft.  Partly Furnished         Sri Hartamas
# 26490  Built-up : 1,313 sq. ft.  Partly Furnished              Setapak
#
#       No_of_Bedrooms  No_of_servant_rooms        type  size
# 0                  2                    1   Built-up   1335
# 1                  3                    0   Built-up   1875
# 2                  4                    1   Built-up   1513
# 3                  4                    2  Land area   7200
# 4                  5                    0  Land area   3600
# ...              ...                  ...         ...   ...
# 26486              3                    0   Built-up    915
# 26487              3                    1  Land area   1544
# 26488              1                    0   Built-up    650
# 26489              4                    2   Built-up   3973
# 26490              4                    0   Built-up   1313
#
# [26491 rows x 11 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26491 entries, 0 to 26490
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Price                26491 non-null  int32
#  1   Bathrooms            26491 non-null  int32
#  2   Car Parks            26491 non-null  int32
#  3   Property Type        26491 non-null  object
#  4   Size                 26491 non-null  object
#  5   Furnishing           26491 non-null  object
#  6   area                 26491 non-null  object
#  7   No_of_Bedrooms       26491 non-null  object
#  8   No_of_servant_rooms  26491 non-null  int32
#  9   type                 26491 non-null  object
#  10  size                 26491 non-null  int32
# dtypes: int32(5), object(6)
# memory usage: 1.7+ MB

# %%
# Calculate minimum and maximum size values for studio records
min_size_studio = data.loc[data['No_of_Bedrooms'] == 'Studio', 'size'].min()
max_size_studio = data.loc[data['No_of_Bedrooms'] == 'Studio', 'size'].max()
mean_size_studio = data.loc[data['No_of_Bedrooms'] == 'Studio', 'size'].mean()

print("Minimum size for studio records:", min_size_studio)
print("Maximum size for studio records:", max_size_studio)
print("Mean size for studio records:", mean_size_studio)
# Out:
# Minimum size for studio records: 250
# Maximum size for studio records: 243900
# Mean size for studio records: 1423.7371794871794

# %%
data['No_of_Bedrooms'].value_counts()
# Out:
# No_of_Bedrooms
# 3           13380
# 2            4438
# 4            3945
# 1            1983
# 5            1506
# 6             567
# Studio        312
# 7             222
# 8              80
# 9              20
# 10             18
# 12              5
# 20 Above        4
# 13              4
# 11              3
# 14              2
# 15              1
# 16              1
# Name: count, dtype: int64

# %%
# Create a new column 'studio_apartment'
data['studio_apartment'] = data['No_of_Bedrooms'].apply(lambda x: 1 if x == 'Studio' else 0)
# Out:
# C:\Users\ptejas\AppData\Local\Temp\ipykernel_13904\681213311.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['studio_apartment'] = data['No_of_Bedrooms'].apply(lambda x: 1 if x == 'Studio' else 0)

# %%
# Replace 'studio' values in 'No_of_Bedrooms' column with 0
data['No_of_Bedrooms'].replace({'Studio': 0, '20 Above': 21}, inplace=True)

data
# Out:
# C:\Users\ptejas\AppData\Local\Temp\ipykernel_13904\2864032243.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['No_of_Bedrooms'].replace({'Studio': 0, '20 Above': 21}, inplace=True)
#          Price  Bathrooms  Car Parks               Property Type  \
# 0      1250000          3          2          Serviced Residence
# 1      1030000          4          2        Condominium (Corner)
# 2       900000          3          2        Condominium (Corner)
# 3      5350000          5          4                    Bungalow
# 4      2600000          4          4         Semi-detached House
# ...        ...        ...        ...                         ...
# 26486   750000          2          1                 Condominium
# 26487  1400000          3          2        Condominium (Corner)
# 26488   880000          1          1        Condominium (Corner)
# 26489  2700000          6          3        Condominium (Corner)
# 26490   540000          2          3  Condominium (Intermediate)
#
#                            Size        Furnishing                 area  \
# 0      Built-up : 1,335 sq. ft.   Fully Furnished                 KLCC
# 1      Built-up : 1,875 sq. ft.  Partly Furnished              Dutamas
# 2      Built-up : 1,513 sq. ft.  Partly Furnished          Bukit Jalil
# 3      Land area : 7200 sq. ft.  Partly Furnished  Taman Tun Dr Ismail
# 4      Land area : 3600 sq. ft.  Partly Furnished  Taman Tun Dr Ismail
# ...                         ...               ...                  ...
# 26486    Built-up : 915 sq. ft.  Partly Furnished              Seputeh
# 26487  Land area : 1544 sq. ft.   Fully Furnished           KL Sentral
# 26488    Built-up : 650 sq. ft.  Partly Furnished          KL Eco City
# 26489  Built-up : 3,973 sq. ft.  Partly Furnished         Sri Hartamas
# 26490  Built-up : 1,313 sq. ft.  Partly Furnished              Setapak
#
#       No_of_Bedrooms  No_of_servant_rooms        type  size  studio_apartment
# 0                  2                    1   Built-up   1335                 0
# 1                  3                    0   Built-up   1875                 0
# 2                  4                    1   Built-up   1513                 0
# 3                  4                    2  Land area   7200                 0
# 4                  5                    0  Land area   3600                 0
# ...              ...                  ...         ...   ...               ...
# 26486              3                    0   Built-up    915                 0
# 26487              3                    1  Land area   1544                 0
# 26488              1                    0   Built-up    650                 0
# 26489              4                    2   Built-up   3973                 0
# 26490              4                    0   Built-up   1313                 0
#
# [26491 rows x 12 columns]

# %%
data.studio_apartment.value_counts()
# Out:
# studio_apartment
# 0    26179
# 1      312
# Name: count, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26491 entries, 0 to 26490
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Price                26491 non-null  int32
#  1   Bathrooms            26491 non-null  int32
#  2   Car Parks            26491 non-null  int32
#  3   Property Type        26491 non-null  object
#  4   Size                 26491 non-null  object
#  5   Furnishing           26491 non-null  object
#  6   area                 26491 non-null  object
#  7   No_of_Bedrooms       26491 non-null  object
#  8   No_of_servant_rooms  26491 non-null  int32
#  9   type                 26491 non-null  object
#  10  size                 26491 non-null  int32
#  11  studio_apartment     26491 non-null  int64
# dtypes: int32(5), int64(1), object(6)
# memory usage: 1.9+ MB

# %%
data['No_of_Bedrooms']=data['No_of_Bedrooms'].astype(int)
# Out:
# C:\Users\ptejas\AppData\Local\Temp\ipykernel_13904\1804879422.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['No_of_Bedrooms']=data['No_of_Bedrooms'].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26491 entries, 0 to 26490
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Price                26491 non-null  int32
#  1   Bathrooms            26491 non-null  int32
#  2   Car Parks            26491 non-null  int32
#  3   Property Type        26491 non-null  object
#  4   Size                 26491 non-null  object
#  5   Furnishing           26491 non-null  object
#  6   area                 26491 non-null  object
#  7   No_of_Bedrooms       26491 non-null  int32
#  8   No_of_servant_rooms  26491 non-null  int32
#  9   type                 26491 non-null  object
#  10  size                 26491 non-null  int32
#  11  studio_apartment     26491 non-null  int64
# dtypes: int32(6), int64(1), object(5)
# memory usage: 1.8+ MB

# %%
data.

# %%
data.to_csv('Ready_to_encode_KLdata.csv')
